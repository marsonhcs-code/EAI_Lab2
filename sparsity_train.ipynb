# %% [markdown]
# ## 掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/your own folder/

# %% [markdown]
# ## Import library

# %%
# !pip install thop
# !pip install torchsummary
# !pip install matplotlib
# Out:
# Requirement already satisfied: thop in ./.venv/lib/python3.12/site-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch->thop) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.12/site-packages (from torch->thop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.venv/lib/python3.12/site-packages (from torch->thop) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.venv/lib/python3.12/site-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch->thop) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.12/site-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch->thop) (2.1.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchsummary in ./.venv/lib/python3.12/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from models.resnet import ResNet50

# %% [markdown]
# ## FLOPs & Parameters & Architecture
# 若`resnet.py`有寫對，這部分會能夠正常跑，且 parameters 應為 23513162。
#
# 你也可以寫一個剪枝後可能的 cfg 作為模型的輸入參數，看這部分印出來的架構是否正確。

# %%
from thop import profile
from torchsummary import summary

model = ResNet50(num_classes=10)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 329439232.0
# Params: 23520842.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              ReLU-15          [-1, 256, 16, 16]               0
#        Bottleneck-16          [-1, 256, 16, 16]               0
#            Conv2d-17           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-18           [-1, 64, 16, 16]             128
#              ReLU-19           [-1, 64, 16, 16]               0
#            Conv2d-20           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-21           [-1, 64, 16, 16]             128
#              ReLU-22           [-1, 64, 16, 16]               0
#            Conv2d-23          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-24          [-1, 256, 16, 16]             512
#              ReLU-25          [-1, 256, 16, 16]               0
#        Bottleneck-26          [-1, 256, 16, 16]               0
#            Conv2d-27           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-28           [-1, 64, 16, 16]             128
#              ReLU-29           [-1, 64, 16, 16]               0
#            Conv2d-30           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-31           [-1, 64, 16, 16]             128
#              ReLU-32           [-1, 64, 16, 16]               0
#            Conv2d-33          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-34          [-1, 256, 16, 16]             512
#              ReLU-35          [-1, 256, 16, 16]               0
#        Bottleneck-36          [-1, 256, 16, 16]               0
#            Conv2d-37          [-1, 128, 16, 16]          32,768
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#              ReLU-39          [-1, 128, 16, 16]               0
#            Conv2d-40            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-41            [-1, 128, 8, 8]             256
#              ReLU-42            [-1, 128, 8, 8]               0
#            Conv2d-43            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-44            [-1, 512, 8, 8]           1,024
#            Conv2d-45            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-46            [-1, 512, 8, 8]           1,024
#              ReLU-47            [-1, 512, 8, 8]               0
#        Bottleneck-48            [-1, 512, 8, 8]               0
#            Conv2d-49            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-50            [-1, 128, 8, 8]             256
#              ReLU-51            [-1, 128, 8, 8]               0
#            Conv2d-52            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-53            [-1, 128, 8, 8]             256
#              ReLU-54            [-1, 128, 8, 8]               0
#            Conv2d-55            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-56            [-1, 512, 8, 8]           1,024
#              ReLU-57            [-1, 512, 8, 8]               0
#        Bottleneck-58            [-1, 512, 8, 8]               0
#            Conv2d-59            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-60            [-1, 128, 8, 8]             256
#              ReLU-61            [-1, 128, 8, 8]               0
#            Conv2d-62            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-63            [-1, 128, 8, 8]             256
#              ReLU-64            [-1, 128, 8, 8]               0
#            Conv2d-65            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-66            [-1, 512, 8, 8]           1,024
#              ReLU-67            [-1, 512, 8, 8]               0
#        Bottleneck-68            [-1, 512, 8, 8]               0
#            Conv2d-69            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-70            [-1, 128, 8, 8]             256
#              ReLU-71            [-1, 128, 8, 8]               0
#            Conv2d-72            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-73            [-1, 128, 8, 8]             256
#              ReLU-74            [-1, 128, 8, 8]               0
#            Conv2d-75            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-76            [-1, 512, 8, 8]           1,024
#              ReLU-77            [-1, 512, 8, 8]               0
#        Bottleneck-78            [-1, 512, 8, 8]               0
#            Conv2d-79            [-1, 256, 8, 8]         131,072
#       BatchNorm2d-80            [-1, 256, 8, 8]             512
#              ReLU-81            [-1, 256, 8, 8]               0
#            Conv2d-82            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-83            [-1, 256, 4, 4]             512
#              ReLU-84            [-1, 256, 4, 4]               0
#            Conv2d-85           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-86           [-1, 1024, 4, 4]           2,048
#            Conv2d-87           [-1, 1024, 4, 4]         524,288
#       BatchNorm2d-88           [-1, 1024, 4, 4]           2,048
#              ReLU-89           [-1, 1024, 4, 4]               0
#        Bottleneck-90           [-1, 1024, 4, 4]               0
#            Conv2d-91            [-1, 256, 4, 4]         262,144
#       BatchNorm2d-92            [-1, 256, 4, 4]             512
#              ReLU-93            [-1, 256, 4, 4]               0
#            Conv2d-94            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-95            [-1, 256, 4, 4]             512
#              ReLU-96            [-1, 256, 4, 4]               0
#            Conv2d-97           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-98           [-1, 1024, 4, 4]           2,048
#              ReLU-99           [-1, 1024, 4, 4]               0
#       Bottleneck-100           [-1, 1024, 4, 4]               0
#           Conv2d-101            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-102            [-1, 256, 4, 4]             512
#             ReLU-103            [-1, 256, 4, 4]               0
#           Conv2d-104            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-105            [-1, 256, 4, 4]             512
#             ReLU-106            [-1, 256, 4, 4]               0
#           Conv2d-107           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-108           [-1, 1024, 4, 4]           2,048
#             ReLU-109           [-1, 1024, 4, 4]               0
#       Bottleneck-110           [-1, 1024, 4, 4]               0
#           Conv2d-111            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-112            [-1, 256, 4, 4]             512
#             ReLU-113            [-1, 256, 4, 4]               0
#           Conv2d-114            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-115            [-1, 256, 4, 4]             512
#             ReLU-116            [-1, 256, 4, 4]               0
#           Conv2d-117           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-118           [-1, 1024, 4, 4]           2,048
#             ReLU-119           [-1, 1024, 4, 4]               0
#       Bottleneck-120           [-1, 1024, 4, 4]               0
#           Conv2d-121            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-122            [-1, 256, 4, 4]             512
#             ReLU-123            [-1, 256, 4, 4]               0
#           Conv2d-124            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-125            [-1, 256, 4, 4]             512
#             ReLU-126            [-1, 256, 4, 4]               0
#           Conv2d-127           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-128           [-1, 1024, 4, 4]           2,048
#             ReLU-129           [-1, 1024, 4, 4]               0
#       Bottleneck-130           [-1, 1024, 4, 4]               0
#           Conv2d-131            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-132            [-1, 256, 4, 4]             512
#             ReLU-133            [-1, 256, 4, 4]               0
#           Conv2d-134            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-135            [-1, 256, 4, 4]             512
#             ReLU-136            [-1, 256, 4, 4]               0
#           Conv2d-137           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-138           [-1, 1024, 4, 4]           2,048
#             ReLU-139           [-1, 1024, 4, 4]               0
#       Bottleneck-140           [-1, 1024, 4, 4]               0
#           Conv2d-141            [-1, 512, 4, 4]         524,288
#      BatchNorm2d-142            [-1, 512, 4, 4]           1,024
#             ReLU-143            [-1, 512, 4, 4]               0
#           Conv2d-144            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-145            [-1, 512, 2, 2]           1,024
#             ReLU-146            [-1, 512, 2, 2]               0
#           Conv2d-147           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 2, 2]           4,096
#           Conv2d-149           [-1, 2048, 2, 2]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 2, 2]           4,096
#             ReLU-151           [-1, 2048, 2, 2]               0
#       Bottleneck-152           [-1, 2048, 2, 2]               0
#           Conv2d-153            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-154            [-1, 512, 2, 2]           1,024
#             ReLU-155            [-1, 512, 2, 2]               0
#           Conv2d-156            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-157            [-1, 512, 2, 2]           1,024
#             ReLU-158            [-1, 512, 2, 2]               0
#           Conv2d-159           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 2, 2]           4,096
#             ReLU-161           [-1, 2048, 2, 2]               0
#       Bottleneck-162           [-1, 2048, 2, 2]               0
#           Conv2d-163            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-164            [-1, 512, 2, 2]           1,024
#             ReLU-165            [-1, 512, 2, 2]               0
#           Conv2d-166            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-167            [-1, 512, 2, 2]           1,024
#             ReLU-168            [-1, 512, 2, 2]               0
#           Conv2d-169           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 2, 2]           4,096
#             ReLU-171           [-1, 2048, 2, 2]               0
#       Bottleneck-172           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 23,520,842
# Trainable params: 23,520,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 23.41
# Params size (MB): 89.72
# Estimated Total Size (MB): 113.14
# ----------------------------------------------------------------

# %% [markdown]
# ## 設定超參數(請填空 λ)

# %%
SPARSITY_REGULARIZATION = True
#### 設定λ(balance factor) ####
################################################
#          請填空          #
################################################
LAMBDA = 1e-4  # 0 or 1e-5 or 1e-4

SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000

EPOCHS = 40
LEARNING_RATE = 1e-3

LOG_INTERVAL = 100
CUDA = True

RESUME = False
START_EPOCH = 0

WEIGHT_PATH = 'model_best.pth' # Change to your own folder !!!

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### 資料集 ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 定義模型與設定Optimizer & CrossEntropy Loss

# %%
# cfg = [64, 64, 64, 256, 64, 64, 256, 64, 64, 256, 128, 128, 512, 128, 128, 512, 128, 128, 512, 128, 128, 512, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 512, 512, 2048, 512, 512, 2048, 512, 512, 2048]

model = ResNet50(num_classes=10)
if CUDA:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 使用論文中稀疏化的方式更新參數(請填空)

# %%
def updateBN():
  for m in model.modules():
      if isinstance(m, nn.BatchNorm2d):
          #### 完成Sparsity Regularization ####
          ################################################
          #          請填空          #
          ################################################
          
          # 在稀疏化訓練中，對 BN 的 weight 加上梯度 = λ * sign(weight)
          m.weight.grad.data.add_(LAMBDA * torch.sign(m.weight.data))

# %% [markdown]
# ## 定義訓練跟測試函數
# 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

train_acc_list = []
test_acc_list = []

def train(epoch):
    model.train()
    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()

        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)

        loss = criterion(output, target)
        loss.backward()

        # ----------- Sparsity Regularization -----------
        if SPARSITY_REGULARIZATION:
            updateBN()
        optimizer.step()
        # ------------------------------------------------

        # === 計算本 batch 正確數 ===
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum().item()
        total += target.size(0)

        # === 每 LOG_INTERVAL 顯示一次訓練狀態 ===
        if batch_idx % LOG_INTERVAL == 0:
            print('Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

    # === 計算整個 epoch 的訓練集準確率 ===
    acc = correct / total
    train_acc_list.append(acc)
    print(f'Epoch {epoch}: Train Accuracy = {acc:.4f}')


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            if CUDA:
                data, target = data.cuda(), target.cuda()
            data, target = Variable(data), Variable(target)

            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item() * data.size(0)

            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / float(len(test_loader.dataset))
    test_acc_list.append(acc)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return acc


##########################################################################################

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate 在 0.5EPOCHS 與 0.75EPOCHS 調整為原本 1/10
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1

    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便後續剪枝與微調
    if prec1 > best_prec1:
        best_prec1 = prec1
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, WEIGHT_PATH)

    best_prec1 = max(prec1, best_prec1)
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.496132
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 1.913829
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.727952
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.581712
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.320383
# Epoch 0: Train Accuracy = 0.3776
#
# Test set: Average loss: 1.4184, Accuracy: 4790/10000 (47.9%)
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.400054
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.337088
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.476903
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.349478
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.134284
# Epoch 1: Train Accuracy = 0.5524
#
# Test set: Average loss: 1.3067, Accuracy: 5614/10000 (56.1%)
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 1.203678
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 1.150680
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.048790
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 1.044511
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 1.080635
# Epoch 2: Train Accuracy = 0.6419
#
# Test set: Average loss: 0.9060, Accuracy: 6762/10000 (67.6%)
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.955328
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.787477
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.912768
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 1.022175
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.804816
# Epoch 3: Train Accuracy = 0.7025
#
# Test set: Average loss: 0.8175, Accuracy: 7245/10000 (72.5%)
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.703662
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.693444
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.606194
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.643923
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.802815
# Epoch 4: Train Accuracy = 0.7420
#
# Test set: Average loss: 0.7290, Accuracy: 7476/10000 (74.8%)
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.699246
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.855879
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.575835
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.536283
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.564089
# Epoch 5: Train Accuracy = 0.7662
#
# Test set: Average loss: 0.6497, Accuracy: 7819/10000 (78.2%)
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.576757
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.581315
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.532139
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.489614
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.522503
# Epoch 6: Train Accuracy = 0.7903
#
# Test set: Average loss: 0.7042, Accuracy: 7661/10000 (76.6%)
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.374785
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.714149
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.482049
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.541454
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.473952
# Epoch 7: Train Accuracy = 0.8056
#
# Test set: Average loss: 0.5514, Accuracy: 8132/10000 (81.3%)
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.635285
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.625312
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.617886
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.402531
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.452811
# Epoch 8: Train Accuracy = 0.8173
#
# Test set: Average loss: 0.5881, Accuracy: 8002/10000 (80.0%)
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.375508
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.582915
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.445483
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.407190
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.399056
# Epoch 9: Train Accuracy = 0.8305
#
# Test set: Average loss: 0.6148, Accuracy: 7986/10000 (79.9%)
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.364974
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.435569
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.607881
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.635911
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.338408
# Epoch 10: Train Accuracy = 0.8429
#
# Test set: Average loss: 0.5461, Accuracy: 8169/10000 (81.7%)
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.555499
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.323263
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.513137
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.522145
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.355895
# Epoch 11: Train Accuracy = 0.8484
#
# Test set: Average loss: 0.4743, Accuracy: 8401/10000 (84.0%)
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.561020
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.307975
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.339299
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.432770
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.389822
# Epoch 12: Train Accuracy = 0.8579
#
# Test set: Average loss: 0.4673, Accuracy: 8421/10000 (84.2%)
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.363179
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.596945
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.400368
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.420789
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.406642
# Epoch 13: Train Accuracy = 0.8673
#
# Test set: Average loss: 0.4274, Accuracy: 8585/10000 (85.8%)
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.364906
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.340691
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.418258
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.435708
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.301678
# Epoch 14: Train Accuracy = 0.8726
#
# Test set: Average loss: 0.4477, Accuracy: 8481/10000 (84.8%)
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.413325
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.375848
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.211285
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.500731
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.380375
# Epoch 15: Train Accuracy = 0.8790
#
# Test set: Average loss: 0.4211, Accuracy: 8614/10000 (86.1%)
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.368430
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.481307
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.270208
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.303494
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.226680
# Epoch 16: Train Accuracy = 0.8819
#
# Test set: Average loss: 0.4593, Accuracy: 8484/10000 (84.8%)
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.372495
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.433647
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.175827
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.281284
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.270570
# Epoch 17: Train Accuracy = 0.8886
#
# Test set: Average loss: 0.3857, Accuracy: 8681/10000 (86.8%)
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.246443
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.368414
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.274137
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.183233
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.371807
# Epoch 18: Train Accuracy = 0.8935
#
# Test set: Average loss: 0.3888, Accuracy: 8666/10000 (86.7%)
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.303746
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.266103
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.321323
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.277589
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.286398
# Epoch 19: Train Accuracy = 0.8992
#
# Test set: Average loss: 0.4300, Accuracy: 8595/10000 (86.0%)
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.241950
# Train Epoch: 20 [10000/50000 (20.0%)]	Loss: 0.237012
# Train Epoch: 20 [20000/50000 (40.0%)]	Loss: 0.171767
# Train Epoch: 20 [30000/50000 (60.0%)]	Loss: 0.117338
# Train Epoch: 20 [40000/50000 (80.0%)]	Loss: 0.137200
# Epoch 20: Train Accuracy = 0.9310
#
# Test set: Average loss: 0.2988, Accuracy: 9017/10000 (90.2%)
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.224172
# Train Epoch: 21 [10000/50000 (20.0%)]	Loss: 0.164091
# Train Epoch: 21 [20000/50000 (40.0%)]	Loss: 0.216975
# Train Epoch: 21 [30000/50000 (60.0%)]	Loss: 0.147475
# Train Epoch: 21 [40000/50000 (80.0%)]	Loss: 0.341266
# Epoch 21: Train Accuracy = 0.9394
#
# Test set: Average loss: 0.2960, Accuracy: 9026/10000 (90.3%)
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.110936
# Train Epoch: 22 [10000/50000 (20.0%)]	Loss: 0.156797
# Train Epoch: 22 [20000/50000 (40.0%)]	Loss: 0.223405
# Train Epoch: 22 [30000/50000 (60.0%)]	Loss: 0.124521
# Train Epoch: 22 [40000/50000 (80.0%)]	Loss: 0.055642
# Epoch 22: Train Accuracy = 0.9444
#
# Test set: Average loss: 0.2964, Accuracy: 9034/10000 (90.3%)
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.213742
# Train Epoch: 23 [10000/50000 (20.0%)]	Loss: 0.182456
# Train Epoch: 23 [20000/50000 (40.0%)]	Loss: 0.198983
# Train Epoch: 23 [30000/50000 (60.0%)]	Loss: 0.224060
# Train Epoch: 23 [40000/50000 (80.0%)]	Loss: 0.188465
# Epoch 23: Train Accuracy = 0.9468
#
# Test set: Average loss: 0.2991, Accuracy: 9040/10000 (90.4%)
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.202858
# Train Epoch: 24 [10000/50000 (20.0%)]	Loss: 0.069235
# Train Epoch: 24 [20000/50000 (40.0%)]	Loss: 0.104137
# Train Epoch: 24 [30000/50000 (60.0%)]	Loss: 0.094908
# Train Epoch: 24 [40000/50000 (80.0%)]	Loss: 0.222541
# Epoch 24: Train Accuracy = 0.9502
#
# Test set: Average loss: 0.2972, Accuracy: 9077/10000 (90.8%)
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.155457
# Train Epoch: 25 [10000/50000 (20.0%)]	Loss: 0.071920
# Train Epoch: 25 [20000/50000 (40.0%)]	Loss: 0.142066
# Train Epoch: 25 [30000/50000 (60.0%)]	Loss: 0.190351
# Train Epoch: 25 [40000/50000 (80.0%)]	Loss: 0.147241
# Epoch 25: Train Accuracy = 0.9515
#
# Test set: Average loss: 0.2936, Accuracy: 9098/10000 (91.0%)
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.131044
# Train Epoch: 26 [10000/50000 (20.0%)]	Loss: 0.155057
# Train Epoch: 26 [20000/50000 (40.0%)]	Loss: 0.143313
# Train Epoch: 26 [30000/50000 (60.0%)]	Loss: 0.125109
# Train Epoch: 26 [40000/50000 (80.0%)]	Loss: 0.155991
# Epoch 26: Train Accuracy = 0.9530
#
# Test set: Average loss: 0.2992, Accuracy: 9064/10000 (90.6%)
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.072175
# Train Epoch: 27 [10000/50000 (20.0%)]	Loss: 0.126791
# Train Epoch: 27 [20000/50000 (40.0%)]	Loss: 0.210055
# Train Epoch: 27 [30000/50000 (60.0%)]	Loss: 0.187556
# Train Epoch: 27 [40000/50000 (80.0%)]	Loss: 0.095750
# Epoch 27: Train Accuracy = 0.9561
#
# Test set: Average loss: 0.3087, Accuracy: 9059/10000 (90.6%)
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.160594
# Train Epoch: 28 [10000/50000 (20.0%)]	Loss: 0.193040
# Train Epoch: 28 [20000/50000 (40.0%)]	Loss: 0.161170
# Train Epoch: 28 [30000/50000 (60.0%)]	Loss: 0.093811
# Train Epoch: 28 [40000/50000 (80.0%)]	Loss: 0.111843
# Epoch 28: Train Accuracy = 0.9576
#
# Test set: Average loss: 0.3077, Accuracy: 9079/10000 (90.8%)
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.115255
# Train Epoch: 29 [10000/50000 (20.0%)]	Loss: 0.092001
# Train Epoch: 29 [20000/50000 (40.0%)]	Loss: 0.188729
# Train Epoch: 29 [30000/50000 (60.0%)]	Loss: 0.144582
# Train Epoch: 29 [40000/50000 (80.0%)]	Loss: 0.079606
# Epoch 29: Train Accuracy = 0.9582
#
# Test set: Average loss: 0.3005, Accuracy: 9096/10000 (91.0%)
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.092441
# Train Epoch: 30 [10000/50000 (20.0%)]	Loss: 0.089941
# Train Epoch: 30 [20000/50000 (40.0%)]	Loss: 0.076226
# Train Epoch: 30 [30000/50000 (60.0%)]	Loss: 0.113807
# Train Epoch: 30 [40000/50000 (80.0%)]	Loss: 0.057205
# Epoch 30: Train Accuracy = 0.9636
#
# Test set: Average loss: 0.2969, Accuracy: 9111/10000 (91.1%)
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.096950
# Train Epoch: 31 [10000/50000 (20.0%)]	Loss: 0.150958
# Train Epoch: 31 [20000/50000 (40.0%)]	Loss: 0.135927
# Train Epoch: 31 [30000/50000 (60.0%)]	Loss: 0.118863
# Train Epoch: 31 [40000/50000 (80.0%)]	Loss: 0.033895
# Epoch 31: Train Accuracy = 0.9629
#
# Test set: Average loss: 0.2981, Accuracy: 9113/10000 (91.1%)
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.195954
# Train Epoch: 32 [10000/50000 (20.0%)]	Loss: 0.100046
# Train Epoch: 32 [20000/50000 (40.0%)]	Loss: 0.027495
# Train Epoch: 32 [30000/50000 (60.0%)]	Loss: 0.079065
# Train Epoch: 32 [40000/50000 (80.0%)]	Loss: 0.073631
# Epoch 32: Train Accuracy = 0.9643
#
# Test set: Average loss: 0.3011, Accuracy: 9097/10000 (91.0%)
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.130457
# Train Epoch: 33 [10000/50000 (20.0%)]	Loss: 0.103350
# Train Epoch: 33 [20000/50000 (40.0%)]	Loss: 0.071265
# Train Epoch: 33 [30000/50000 (60.0%)]	Loss: 0.126230
# Train Epoch: 33 [40000/50000 (80.0%)]	Loss: 0.248259
# Epoch 33: Train Accuracy = 0.9646
#
# Test set: Average loss: 0.3009, Accuracy: 9099/10000 (91.0%)
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.049587
# Train Epoch: 34 [10000/50000 (20.0%)]	Loss: 0.122007
# Train Epoch: 34 [20000/50000 (40.0%)]	Loss: 0.085264
# Train Epoch: 34 [30000/50000 (60.0%)]	Loss: 0.061306
# Train Epoch: 34 [40000/50000 (80.0%)]	Loss: 0.079245
# Epoch 34: Train Accuracy = 0.9652
#
# Test set: Average loss: 0.3020, Accuracy: 9095/10000 (91.0%)
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.123556
# Train Epoch: 35 [10000/50000 (20.0%)]	Loss: 0.218564
# Train Epoch: 35 [20000/50000 (40.0%)]	Loss: 0.174594
# Train Epoch: 35 [30000/50000 (60.0%)]	Loss: 0.115897
# Train Epoch: 35 [40000/50000 (80.0%)]	Loss: 0.073063
# Epoch 35: Train Accuracy = 0.9647
#
# Test set: Average loss: 0.3004, Accuracy: 9119/10000 (91.2%)
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.078954
# Train Epoch: 36 [10000/50000 (20.0%)]	Loss: 0.095403
# Train Epoch: 36 [20000/50000 (40.0%)]	Loss: 0.120547
# Train Epoch: 36 [30000/50000 (60.0%)]	Loss: 0.135207
# Train Epoch: 36 [40000/50000 (80.0%)]	Loss: 0.070251
# Epoch 36: Train Accuracy = 0.9663
#
# Test set: Average loss: 0.3041, Accuracy: 9105/10000 (91.0%)
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.088140
# Train Epoch: 37 [10000/50000 (20.0%)]	Loss: 0.066530
# Train Epoch: 37 [20000/50000 (40.0%)]	Loss: 0.083908
# Train Epoch: 37 [30000/50000 (60.0%)]	Loss: 0.118977
# Train Epoch: 37 [40000/50000 (80.0%)]	Loss: 0.076924
# Epoch 37: Train Accuracy = 0.9634
#
# Test set: Average loss: 0.3032, Accuracy: 9106/10000 (91.1%)
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.110738
# Train Epoch: 38 [10000/50000 (20.0%)]	Loss: 0.183307
# Train Epoch: 38 [20000/50000 (40.0%)]	Loss: 0.064060
# Train Epoch: 38 [30000/50000 (60.0%)]	Loss: 0.062720
# Train Epoch: 38 [40000/50000 (80.0%)]	Loss: 0.173601
# Epoch 38: Train Accuracy = 0.9654
#
# Test set: Average loss: 0.3000, Accuracy: 9100/10000 (91.0%)
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.077456
# Train Epoch: 39 [10000/50000 (20.0%)]	Loss: 0.057644
# Train Epoch: 39 [20000/50000 (40.0%)]	Loss: 0.073352
# Train Epoch: 39 [30000/50000 (60.0%)]	Loss: 0.055114
# Train Epoch: 39 [40000/50000 (80.0%)]	Loss: 0.148337
# Epoch 39: Train Accuracy = 0.9662
#
# Test set: Average loss: 0.3036, Accuracy: 9093/10000 (90.9%)

# %% [markdown]
# ## 繪製Sparsity-Training結果圖

# %%
save_dir = "./results"
os.makedirs(save_dir, exist_ok=True)

# %%
#繪製 Sparsity-Training 結果圖



epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(8,5))
plt.plot(epochs, train_acc_list, label='Train Accuracy', marker='o')
plt.plot(epochs, test_acc_list, label='Test Accuracy', marker='s')
plt.title(f"Sparsity Training (λ = {LAMBDA})")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()

save_path = os.path.join(save_dir, f"sparsity_training_acc_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()

# %% [markdown]
# ## 繪製scaling factor 分布圖

# %%
#繪製 scaling factor 分布圖


all_gamma = []
for m in model.modules():
    if isinstance(m, nn.BatchNorm2d):
        all_gamma.append(m.weight.data.abs().cpu().numpy())

# 合併所有 γ 值
all_gamma = np.concatenate(all_gamma)

plt.figure(figsize=(7,4))
plt.hist(all_gamma, bins=80, color='skyblue', edgecolor='k', alpha=0.7)
plt.title(f"Distribution of BN Scaling Factors (λ = {LAMBDA})")
plt.xlabel("γ (BatchNorm scale)")
plt.ylabel("Frequency")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()



save_path = os.path.join(save_dir, f"bn_distribution_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()
