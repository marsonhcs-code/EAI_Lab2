# %% [markdown]
# ## 掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/your own folder/

# %% [markdown]
# ## Import library

# %%
# !pip install thop
# !pip install torchsummary
# !pip install matplotlib
# Out:
# Requirement already satisfied: thop in ./.venv/lib/python3.12/site-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch->thop) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.12/site-packages (from torch->thop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.venv/lib/python3.12/site-packages (from torch->thop) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.venv/lib/python3.12/site-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch->thop) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.12/site-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch->thop) (2.1.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchsummary in ./.venv/lib/python3.12/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from models.resnet import ResNet50

# %% [markdown]
# ## FLOPs & Parameters & Architecture
# 若`resnet.py`有寫對，這部分會能夠正常跑，且 parameters 應為 23513162。
#
# 你也可以寫一個剪枝後可能的 cfg 作為模型的輸入參數，看這部分印出來的架構是否正確。

# %%
from thop import profile
from torchsummary import summary

model = ResNet50(num_classes=10)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 329439232.0
# Params: 23520842.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              ReLU-15          [-1, 256, 16, 16]               0
#        Bottleneck-16          [-1, 256, 16, 16]               0
#            Conv2d-17           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-18           [-1, 64, 16, 16]             128
#              ReLU-19           [-1, 64, 16, 16]               0
#            Conv2d-20           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-21           [-1, 64, 16, 16]             128
#              ReLU-22           [-1, 64, 16, 16]               0
#            Conv2d-23          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-24          [-1, 256, 16, 16]             512
#              ReLU-25          [-1, 256, 16, 16]               0
#        Bottleneck-26          [-1, 256, 16, 16]               0
#            Conv2d-27           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-28           [-1, 64, 16, 16]             128
#              ReLU-29           [-1, 64, 16, 16]               0
#            Conv2d-30           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-31           [-1, 64, 16, 16]             128
#              ReLU-32           [-1, 64, 16, 16]               0
#            Conv2d-33          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-34          [-1, 256, 16, 16]             512
#              ReLU-35          [-1, 256, 16, 16]               0
#        Bottleneck-36          [-1, 256, 16, 16]               0
#            Conv2d-37          [-1, 128, 16, 16]          32,768
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#              ReLU-39          [-1, 128, 16, 16]               0
#            Conv2d-40            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-41            [-1, 128, 8, 8]             256
#              ReLU-42            [-1, 128, 8, 8]               0
#            Conv2d-43            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-44            [-1, 512, 8, 8]           1,024
#            Conv2d-45            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-46            [-1, 512, 8, 8]           1,024
#              ReLU-47            [-1, 512, 8, 8]               0
#        Bottleneck-48            [-1, 512, 8, 8]               0
#            Conv2d-49            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-50            [-1, 128, 8, 8]             256
#              ReLU-51            [-1, 128, 8, 8]               0
#            Conv2d-52            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-53            [-1, 128, 8, 8]             256
#              ReLU-54            [-1, 128, 8, 8]               0
#            Conv2d-55            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-56            [-1, 512, 8, 8]           1,024
#              ReLU-57            [-1, 512, 8, 8]               0
#        Bottleneck-58            [-1, 512, 8, 8]               0
#            Conv2d-59            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-60            [-1, 128, 8, 8]             256
#              ReLU-61            [-1, 128, 8, 8]               0
#            Conv2d-62            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-63            [-1, 128, 8, 8]             256
#              ReLU-64            [-1, 128, 8, 8]               0
#            Conv2d-65            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-66            [-1, 512, 8, 8]           1,024
#              ReLU-67            [-1, 512, 8, 8]               0
#        Bottleneck-68            [-1, 512, 8, 8]               0
#            Conv2d-69            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-70            [-1, 128, 8, 8]             256
#              ReLU-71            [-1, 128, 8, 8]               0
#            Conv2d-72            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-73            [-1, 128, 8, 8]             256
#              ReLU-74            [-1, 128, 8, 8]               0
#            Conv2d-75            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-76            [-1, 512, 8, 8]           1,024
#              ReLU-77            [-1, 512, 8, 8]               0
#        Bottleneck-78            [-1, 512, 8, 8]               0
#            Conv2d-79            [-1, 256, 8, 8]         131,072
#       BatchNorm2d-80            [-1, 256, 8, 8]             512
#              ReLU-81            [-1, 256, 8, 8]               0
#            Conv2d-82            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-83            [-1, 256, 4, 4]             512
#              ReLU-84            [-1, 256, 4, 4]               0
#            Conv2d-85           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-86           [-1, 1024, 4, 4]           2,048
#            Conv2d-87           [-1, 1024, 4, 4]         524,288
#       BatchNorm2d-88           [-1, 1024, 4, 4]           2,048
#              ReLU-89           [-1, 1024, 4, 4]               0
#        Bottleneck-90           [-1, 1024, 4, 4]               0
#            Conv2d-91            [-1, 256, 4, 4]         262,144
#       BatchNorm2d-92            [-1, 256, 4, 4]             512
#              ReLU-93            [-1, 256, 4, 4]               0
#            Conv2d-94            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-95            [-1, 256, 4, 4]             512
#              ReLU-96            [-1, 256, 4, 4]               0
#            Conv2d-97           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-98           [-1, 1024, 4, 4]           2,048
#              ReLU-99           [-1, 1024, 4, 4]               0
#       Bottleneck-100           [-1, 1024, 4, 4]               0
#           Conv2d-101            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-102            [-1, 256, 4, 4]             512
#             ReLU-103            [-1, 256, 4, 4]               0
#           Conv2d-104            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-105            [-1, 256, 4, 4]             512
#             ReLU-106            [-1, 256, 4, 4]               0
#           Conv2d-107           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-108           [-1, 1024, 4, 4]           2,048
#             ReLU-109           [-1, 1024, 4, 4]               0
#       Bottleneck-110           [-1, 1024, 4, 4]               0
#           Conv2d-111            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-112            [-1, 256, 4, 4]             512
#             ReLU-113            [-1, 256, 4, 4]               0
#           Conv2d-114            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-115            [-1, 256, 4, 4]             512
#             ReLU-116            [-1, 256, 4, 4]               0
#           Conv2d-117           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-118           [-1, 1024, 4, 4]           2,048
#             ReLU-119           [-1, 1024, 4, 4]               0
#       Bottleneck-120           [-1, 1024, 4, 4]               0
#           Conv2d-121            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-122            [-1, 256, 4, 4]             512
#             ReLU-123            [-1, 256, 4, 4]               0
#           Conv2d-124            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-125            [-1, 256, 4, 4]             512
#             ReLU-126            [-1, 256, 4, 4]               0
#           Conv2d-127           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-128           [-1, 1024, 4, 4]           2,048
#             ReLU-129           [-1, 1024, 4, 4]               0
#       Bottleneck-130           [-1, 1024, 4, 4]               0
#           Conv2d-131            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-132            [-1, 256, 4, 4]             512
#             ReLU-133            [-1, 256, 4, 4]               0
#           Conv2d-134            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-135            [-1, 256, 4, 4]             512
#             ReLU-136            [-1, 256, 4, 4]               0
#           Conv2d-137           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-138           [-1, 1024, 4, 4]           2,048
#             ReLU-139           [-1, 1024, 4, 4]               0
#       Bottleneck-140           [-1, 1024, 4, 4]               0
#           Conv2d-141            [-1, 512, 4, 4]         524,288
#      BatchNorm2d-142            [-1, 512, 4, 4]           1,024
#             ReLU-143            [-1, 512, 4, 4]               0
#           Conv2d-144            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-145            [-1, 512, 2, 2]           1,024
#             ReLU-146            [-1, 512, 2, 2]               0
#           Conv2d-147           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 2, 2]           4,096
#           Conv2d-149           [-1, 2048, 2, 2]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 2, 2]           4,096
#             ReLU-151           [-1, 2048, 2, 2]               0
#       Bottleneck-152           [-1, 2048, 2, 2]               0
#           Conv2d-153            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-154            [-1, 512, 2, 2]           1,024
#             ReLU-155            [-1, 512, 2, 2]               0
#           Conv2d-156            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-157            [-1, 512, 2, 2]           1,024
#             ReLU-158            [-1, 512, 2, 2]               0
#           Conv2d-159           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 2, 2]           4,096
#             ReLU-161           [-1, 2048, 2, 2]               0
#       Bottleneck-162           [-1, 2048, 2, 2]               0
#           Conv2d-163            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-164            [-1, 512, 2, 2]           1,024
#             ReLU-165            [-1, 512, 2, 2]               0
#           Conv2d-166            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-167            [-1, 512, 2, 2]           1,024
#             ReLU-168            [-1, 512, 2, 2]               0
#           Conv2d-169           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 2, 2]           4,096
#             ReLU-171           [-1, 2048, 2, 2]               0
#       Bottleneck-172           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 23,520,842
# Trainable params: 23,520,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 23.41
# Params size (MB): 89.72
# Estimated Total Size (MB): 113.14
# ----------------------------------------------------------------

# %% [markdown]
# ## 設定超參數(請填空 λ)

# %%
SPARSITY_REGULARIZATION = True
#### 設定λ(balance factor) ####
################################################
#          請填空          #
################################################
LAMBDA = 1e-4  # 0 or 1e-5 or 1e-4

SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000

EPOCHS = 40
LEARNING_RATE = 1e-3

LOG_INTERVAL = 100
CUDA = True

RESUME = False
START_EPOCH = 0

WEIGHT_PATH = 'model_best.pth' # Change to your own folder !!!

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### 資料集 ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 定義模型與設定Optimizer & CrossEntropy Loss

# %%
model = ResNet50(num_classes=10)
if CUDA:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 使用論文中稀疏化的方式更新參數(請填空)

# %%
def updateBN():
  for m in model.modules():
      if isinstance(m, nn.BatchNorm2d):
          #### 完成Sparsity Regularization ####
          ################################################
          #          請填空          #
          ################################################
          
          # 在稀疏化訓練中，對 BN 的 weight 加上梯度 = λ * sign(weight)
          m.weight.grad.data.add_(LAMBDA * torch.sign(m.weight.data))

# %% [markdown]
# ## 定義訓練跟測試函數
# 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

train_acc_list = []
test_acc_list = []

def train(epoch):
    model.train()
    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()

        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)

        loss = criterion(output, target)
        loss.backward()

        # ----------- Sparsity Regularization -----------
        if SPARSITY_REGULARIZATION:
            updateBN()
        optimizer.step()
        # ------------------------------------------------

        # === 計算本 batch 正確數 ===
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum().item()
        total += target.size(0)

        # === 每 LOG_INTERVAL 顯示一次訓練狀態 ===
        if batch_idx % LOG_INTERVAL == 0:
            print('Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

    # === 計算整個 epoch 的訓練集準確率 ===
    acc = correct / total
    train_acc_list.append(acc)
    print(f'Epoch {epoch}: Train Accuracy = {acc:.4f}')


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            if CUDA:
                data, target = data.cuda(), target.cuda()
            data, target = Variable(data), Variable(target)

            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item() * data.size(0)

            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / float(len(test_loader.dataset))
    test_acc_list.append(acc)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return acc


##########################################################################################

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate 在 0.5EPOCHS 與 0.75EPOCHS 調整為原本 1/10
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1

    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便後續剪枝與微調
    if prec1 > best_prec1:
        best_prec1 = prec1
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, WEIGHT_PATH)

    best_prec1 = max(prec1, best_prec1)
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.632343
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 2.176511
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.569066
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.769529
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.478976
# Epoch 0: Train Accuracy = 0.3894
#
# Test set: Average loss: 1.5415, Accuracy: 4970/10000 (49.7%)
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.289648
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.447024
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.204293
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 0.950891
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.028317
# Epoch 1: Train Accuracy = 0.5678
#
# Test set: Average loss: 1.1066, Accuracy: 6123/10000 (61.2%)
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.941795
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.958644
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.069117
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.769616
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.824385
# Epoch 2: Train Accuracy = 0.6646
#
# Test set: Average loss: 0.9118, Accuracy: 6795/10000 (68.0%)
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.843015
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.894132
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.775835
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.714251
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.963650
# Epoch 3: Train Accuracy = 0.7205
#
# Test set: Average loss: 0.8983, Accuracy: 7027/10000 (70.3%)
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.997702
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.751848
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.768305
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.825031
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.703661
# Epoch 4: Train Accuracy = 0.7580
#
# Test set: Average loss: 0.6608, Accuracy: 7713/10000 (77.1%)
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.791789
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.530272
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.593451
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.677899
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.817675
# Epoch 5: Train Accuracy = 0.7828
#
# Test set: Average loss: 0.6838, Accuracy: 7713/10000 (77.1%)
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.618343
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.575411
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.567923
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.585595
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.587231
# Epoch 6: Train Accuracy = 0.8019
#
# Test set: Average loss: 0.6258, Accuracy: 7887/10000 (78.9%)
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.392454
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.483085
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.576772
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.556994
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.429554
# Epoch 7: Train Accuracy = 0.8163
#
# Test set: Average loss: 0.5416, Accuracy: 8131/10000 (81.3%)
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.470174
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.421658
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.452399
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.360324
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.503540
# Epoch 8: Train Accuracy = 0.8260
#
# Test set: Average loss: 0.5130, Accuracy: 8252/10000 (82.5%)
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.484667
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.479700
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.547368
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.405318
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.471220
# Epoch 9: Train Accuracy = 0.8386
#
# Test set: Average loss: 0.5297, Accuracy: 8171/10000 (81.7%)
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.337827
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.648223
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.460484
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.488435
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.428381
# Epoch 10: Train Accuracy = 0.8459
#
# Test set: Average loss: 0.5515, Accuracy: 8133/10000 (81.3%)
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.469944
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.420162
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.635875
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.489073
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.343753
# Epoch 11: Train Accuracy = 0.8567
#
# Test set: Average loss: 0.5642, Accuracy: 8106/10000 (81.1%)
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.418710
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.464892
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.424289
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.377240
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.428819
# Epoch 12: Train Accuracy = 0.8636
#
# Test set: Average loss: 0.4749, Accuracy: 8423/10000 (84.2%)
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.353121
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.324346
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.454917
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.331351
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.236836
# Epoch 13: Train Accuracy = 0.8697
#
# Test set: Average loss: 0.4904, Accuracy: 8318/10000 (83.2%)
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.343246
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.406146
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.442919
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.411980
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.343212
# Epoch 14: Train Accuracy = 0.8767
#
# Test set: Average loss: 0.4474, Accuracy: 8519/10000 (85.2%)
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.369040
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.511901
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.270052
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.212376
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.332868
# Epoch 15: Train Accuracy = 0.8813
#
# Test set: Average loss: 0.3971, Accuracy: 8669/10000 (86.7%)
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.314606
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.371766
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.321123
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.445297
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.314134
# Epoch 16: Train Accuracy = 0.8883
#
# Test set: Average loss: 0.4314, Accuracy: 8554/10000 (85.5%)
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.420845
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.288738
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.330509
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.324707
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.437537
# Epoch 17: Train Accuracy = 0.8932
#
# Test set: Average loss: 0.3947, Accuracy: 8677/10000 (86.8%)
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.236809
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.237737
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.229842
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.399220
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.297157
# Epoch 18: Train Accuracy = 0.8971
#
# Test set: Average loss: 0.3701, Accuracy: 8767/10000 (87.7%)
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.266868
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.211836
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.249851
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.224776
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.316528
# Epoch 19: Train Accuracy = 0.9012
#
# Test set: Average loss: 0.3743, Accuracy: 8768/10000 (87.7%)
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.338114
# Train Epoch: 20 [10000/50000 (20.0%)]	Loss: 0.207250
# Train Epoch: 20 [20000/50000 (40.0%)]	Loss: 0.195434
# Train Epoch: 20 [30000/50000 (60.0%)]	Loss: 0.117069
# Train Epoch: 20 [40000/50000 (80.0%)]	Loss: 0.087479
# Epoch 20: Train Accuracy = 0.9340
#
# Test set: Average loss: 0.2911, Accuracy: 9026/10000 (90.3%)
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.146036
# Train Epoch: 21 [10000/50000 (20.0%)]	Loss: 0.202863
# Train Epoch: 21 [20000/50000 (40.0%)]	Loss: 0.094659
# Train Epoch: 21 [30000/50000 (60.0%)]	Loss: 0.127950
# Train Epoch: 21 [40000/50000 (80.0%)]	Loss: 0.272952
# Epoch 21: Train Accuracy = 0.9433
#
# Test set: Average loss: 0.2909, Accuracy: 9070/10000 (90.7%)
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.185384
# Train Epoch: 22 [10000/50000 (20.0%)]	Loss: 0.141084
# Train Epoch: 22 [20000/50000 (40.0%)]	Loss: 0.194508
# Train Epoch: 22 [30000/50000 (60.0%)]	Loss: 0.144841
# Train Epoch: 22 [40000/50000 (80.0%)]	Loss: 0.175715
# Epoch 22: Train Accuracy = 0.9461
#
# Test set: Average loss: 0.2895, Accuracy: 9069/10000 (90.7%)
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.187245
# Train Epoch: 23 [10000/50000 (20.0%)]	Loss: 0.157604
# Train Epoch: 23 [20000/50000 (40.0%)]	Loss: 0.037684
# Train Epoch: 23 [30000/50000 (60.0%)]	Loss: 0.102429
# Train Epoch: 23 [40000/50000 (80.0%)]	Loss: 0.189349
# Epoch 23: Train Accuracy = 0.9494
#
# Test set: Average loss: 0.2939, Accuracy: 9076/10000 (90.8%)
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.096878
# Train Epoch: 24 [10000/50000 (20.0%)]	Loss: 0.096784
# Train Epoch: 24 [20000/50000 (40.0%)]	Loss: 0.065170
# Train Epoch: 24 [30000/50000 (60.0%)]	Loss: 0.181100
# Train Epoch: 24 [40000/50000 (80.0%)]	Loss: 0.124103
# Epoch 24: Train Accuracy = 0.9505
#
# Test set: Average loss: 0.2923, Accuracy: 9076/10000 (90.8%)
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.167473
# Train Epoch: 25 [10000/50000 (20.0%)]	Loss: 0.124075
# Train Epoch: 25 [20000/50000 (40.0%)]	Loss: 0.096679
# Train Epoch: 25 [30000/50000 (60.0%)]	Loss: 0.132621
# Train Epoch: 25 [40000/50000 (80.0%)]	Loss: 0.158660
# Epoch 25: Train Accuracy = 0.9534
#
# Test set: Average loss: 0.2948, Accuracy: 9067/10000 (90.7%)
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.049369
# Train Epoch: 26 [10000/50000 (20.0%)]	Loss: 0.168085
# Train Epoch: 26 [20000/50000 (40.0%)]	Loss: 0.227869
# Train Epoch: 26 [30000/50000 (60.0%)]	Loss: 0.124359
# Train Epoch: 26 [40000/50000 (80.0%)]	Loss: 0.088765
# Epoch 26: Train Accuracy = 0.9559
#
# Test set: Average loss: 0.2974, Accuracy: 9075/10000 (90.8%)
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.094946
# Train Epoch: 27 [10000/50000 (20.0%)]	Loss: 0.143491
# Train Epoch: 27 [20000/50000 (40.0%)]	Loss: 0.141665
# Train Epoch: 27 [30000/50000 (60.0%)]	Loss: 0.103669
# Train Epoch: 27 [40000/50000 (80.0%)]	Loss: 0.127174
# Epoch 27: Train Accuracy = 0.9580
#
# Test set: Average loss: 0.2984, Accuracy: 9090/10000 (90.9%)
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.103703
# Train Epoch: 28 [10000/50000 (20.0%)]	Loss: 0.092605
# Train Epoch: 28 [20000/50000 (40.0%)]	Loss: 0.107754
# Train Epoch: 28 [30000/50000 (60.0%)]	Loss: 0.078611
# Train Epoch: 28 [40000/50000 (80.0%)]	Loss: 0.120499
# Epoch 28: Train Accuracy = 0.9587
#
# Test set: Average loss: 0.2967, Accuracy: 9084/10000 (90.8%)
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.152150
# Train Epoch: 29 [10000/50000 (20.0%)]	Loss: 0.154704
# Train Epoch: 29 [20000/50000 (40.0%)]	Loss: 0.112987
# Train Epoch: 29 [30000/50000 (60.0%)]	Loss: 0.121086
# Train Epoch: 29 [40000/50000 (80.0%)]	Loss: 0.116973
# Epoch 29: Train Accuracy = 0.9592
#
# Test set: Average loss: 0.2994, Accuracy: 9079/10000 (90.8%)
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.114365
# Train Epoch: 30 [10000/50000 (20.0%)]	Loss: 0.033038
# Train Epoch: 30 [20000/50000 (40.0%)]	Loss: 0.083997
# Train Epoch: 30 [30000/50000 (60.0%)]	Loss: 0.118011
# Train Epoch: 30 [40000/50000 (80.0%)]	Loss: 0.041638
# Epoch 30: Train Accuracy = 0.9653
#
# Test set: Average loss: 0.2957, Accuracy: 9091/10000 (90.9%)
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.068719
# Train Epoch: 31 [10000/50000 (20.0%)]	Loss: 0.064272
# Train Epoch: 31 [20000/50000 (40.0%)]	Loss: 0.125303
# Train Epoch: 31 [30000/50000 (60.0%)]	Loss: 0.116238
# Train Epoch: 31 [40000/50000 (80.0%)]	Loss: 0.096177
# Epoch 31: Train Accuracy = 0.9660
#
# Test set: Average loss: 0.2957, Accuracy: 9105/10000 (91.0%)
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.109385
# Train Epoch: 32 [10000/50000 (20.0%)]	Loss: 0.153969
# Train Epoch: 32 [20000/50000 (40.0%)]	Loss: 0.148709
# Train Epoch: 32 [30000/50000 (60.0%)]	Loss: 0.080569
# Train Epoch: 32 [40000/50000 (80.0%)]	Loss: 0.090893
# Epoch 32: Train Accuracy = 0.9662
#
# Test set: Average loss: 0.2979, Accuracy: 9092/10000 (90.9%)
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.165835
# Train Epoch: 33 [10000/50000 (20.0%)]	Loss: 0.095415
# Train Epoch: 33 [20000/50000 (40.0%)]	Loss: 0.098572
# Train Epoch: 33 [30000/50000 (60.0%)]	Loss: 0.103915
# Train Epoch: 33 [40000/50000 (80.0%)]	Loss: 0.139380
# Epoch 33: Train Accuracy = 0.9662
#
# Test set: Average loss: 0.2973, Accuracy: 9089/10000 (90.9%)
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.031243
# Train Epoch: 34 [10000/50000 (20.0%)]	Loss: 0.060659
# Train Epoch: 34 [20000/50000 (40.0%)]	Loss: 0.090764
# Train Epoch: 34 [30000/50000 (60.0%)]	Loss: 0.066351
# Train Epoch: 34 [40000/50000 (80.0%)]	Loss: 0.093540
# Epoch 34: Train Accuracy = 0.9669
#
# Test set: Average loss: 0.2970, Accuracy: 9096/10000 (91.0%)
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.084070
# Train Epoch: 35 [10000/50000 (20.0%)]	Loss: 0.076247
# Train Epoch: 35 [20000/50000 (40.0%)]	Loss: 0.104155
# Train Epoch: 35 [30000/50000 (60.0%)]	Loss: 0.076466
# Train Epoch: 35 [40000/50000 (80.0%)]	Loss: 0.183958
# Epoch 35: Train Accuracy = 0.9668
#
# Test set: Average loss: 0.2980, Accuracy: 9093/10000 (90.9%)
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.110320
# Train Epoch: 36 [10000/50000 (20.0%)]	Loss: 0.092250
# Train Epoch: 36 [20000/50000 (40.0%)]	Loss: 0.216976
# Train Epoch: 36 [30000/50000 (60.0%)]	Loss: 0.129378
# Train Epoch: 36 [40000/50000 (80.0%)]	Loss: 0.060134
# Epoch 36: Train Accuracy = 0.9667
#
# Test set: Average loss: 0.3024, Accuracy: 9086/10000 (90.9%)
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.051099
# Train Epoch: 37 [10000/50000 (20.0%)]	Loss: 0.126678
# Train Epoch: 37 [20000/50000 (40.0%)]	Loss: 0.074350
# Train Epoch: 37 [30000/50000 (60.0%)]	Loss: 0.115965
# Train Epoch: 37 [40000/50000 (80.0%)]	Loss: 0.107132
# Epoch 37: Train Accuracy = 0.9673
#
# Test set: Average loss: 0.2978, Accuracy: 9110/10000 (91.1%)
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.098726
# Train Epoch: 38 [10000/50000 (20.0%)]	Loss: 0.081301
# Train Epoch: 38 [20000/50000 (40.0%)]	Loss: 0.067516
# Train Epoch: 38 [30000/50000 (60.0%)]	Loss: 0.030295
# Train Epoch: 38 [40000/50000 (80.0%)]	Loss: 0.084435
# Epoch 38: Train Accuracy = 0.9668
#
# Test set: Average loss: 0.2997, Accuracy: 9091/10000 (90.9%)
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.077299
# Train Epoch: 39 [10000/50000 (20.0%)]	Loss: 0.037729
# Train Epoch: 39 [20000/50000 (40.0%)]	Loss: 0.126346
# Train Epoch: 39 [30000/50000 (60.0%)]	Loss: 0.113695
# Train Epoch: 39 [40000/50000 (80.0%)]	Loss: 0.092017
# Epoch 39: Train Accuracy = 0.9686
#
# Test set: Average loss: 0.2992, Accuracy: 9102/10000 (91.0%)

# %% [markdown]
# ## 繪製Sparsity-Training結果圖

# %%
save_dir = "./results"
os.makedirs(save_dir, exist_ok=True)

# %%
#繪製 Sparsity-Training 結果圖



epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(8,5))
plt.plot(epochs, train_acc_list, label='Train Accuracy', marker='o')
plt.plot(epochs, test_acc_list, label='Test Accuracy', marker='s')
plt.title(f"Sparsity Training (λ = {LAMBDA})")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()

save_path = os.path.join(save_dir, f"sparsity_training_acc_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()

# %% [markdown]
# ## 繪製scaling factor 分布圖

# %%
#繪製 scaling factor 分布圖


all_gamma = []
for m in model.modules():
    if isinstance(m, nn.BatchNorm2d):
        all_gamma.append(m.weight.data.abs().cpu().numpy())

# 合併所有 γ 值
all_gamma = np.concatenate(all_gamma)

plt.figure(figsize=(7,4))
plt.hist(all_gamma, bins=80, color='skyblue', edgecolor='k', alpha=0.7)
plt.title(f"Distribution of BN Scaling Factors (λ = {LAMBDA})")
plt.xlabel("γ (BatchNorm scale)")
plt.ylabel("Frequency")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()



save_path = os.path.join(save_dir, f"bn_distribution_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()
