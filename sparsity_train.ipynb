# %% [markdown]
# ## 掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/your own folder/

# %% [markdown]
# ## Import library

# %%
# !pip install thop
# !pip install torchsummary
# !pip install matplotlib
# Out:
# Requirement already satisfied: thop in ./.venv/lib/python3.12/site-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in ./.venv/lib/python3.12/site-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch->thop) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.12/site-packages (from torch->thop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./.venv/lib/python3.12/site-packages (from torch->thop) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./.venv/lib/python3.12/site-packages (from torch->thop) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in ./.venv/lib/python3.12/site-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./.venv/lib/python3.12/site-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in ./.venv/lib/python3.12/site-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch->thop) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.12/site-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch->thop) (2.1.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchsummary in ./.venv/lib/python3.12/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from models.resnet import ResNet50

# %% [markdown]
# ## FLOPs & Parameters & Architecture
# 若`resnet.py`有寫對，這部分會能夠正常跑，且 parameters 應為 23513162。
#
# 你也可以寫一個剪枝後可能的 cfg 作為模型的輸入參數，看這部分印出來的架構是否正確。

# %%
from thop import profile
from torchsummary import summary

model = ResNet50(num_classes=10)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 329439232.0
# Params: 23520842.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              ReLU-15          [-1, 256, 16, 16]               0
#        Bottleneck-16          [-1, 256, 16, 16]               0
#            Conv2d-17           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-18           [-1, 64, 16, 16]             128
#              ReLU-19           [-1, 64, 16, 16]               0
#            Conv2d-20           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-21           [-1, 64, 16, 16]             128
#              ReLU-22           [-1, 64, 16, 16]               0
#            Conv2d-23          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-24          [-1, 256, 16, 16]             512
#              ReLU-25          [-1, 256, 16, 16]               0
#        Bottleneck-26          [-1, 256, 16, 16]               0
#            Conv2d-27           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-28           [-1, 64, 16, 16]             128
#              ReLU-29           [-1, 64, 16, 16]               0
#            Conv2d-30           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-31           [-1, 64, 16, 16]             128
#              ReLU-32           [-1, 64, 16, 16]               0
#            Conv2d-33          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-34          [-1, 256, 16, 16]             512
#              ReLU-35          [-1, 256, 16, 16]               0
#        Bottleneck-36          [-1, 256, 16, 16]               0
#            Conv2d-37          [-1, 128, 16, 16]          32,768
#       BatchNorm2d-38          [-1, 128, 16, 16]             256
#              ReLU-39          [-1, 128, 16, 16]               0
#            Conv2d-40            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-41            [-1, 128, 8, 8]             256
#              ReLU-42            [-1, 128, 8, 8]               0
#            Conv2d-43            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-44            [-1, 512, 8, 8]           1,024
#            Conv2d-45            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-46            [-1, 512, 8, 8]           1,024
#              ReLU-47            [-1, 512, 8, 8]               0
#        Bottleneck-48            [-1, 512, 8, 8]               0
#            Conv2d-49            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-50            [-1, 128, 8, 8]             256
#              ReLU-51            [-1, 128, 8, 8]               0
#            Conv2d-52            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-53            [-1, 128, 8, 8]             256
#              ReLU-54            [-1, 128, 8, 8]               0
#            Conv2d-55            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-56            [-1, 512, 8, 8]           1,024
#              ReLU-57            [-1, 512, 8, 8]               0
#        Bottleneck-58            [-1, 512, 8, 8]               0
#            Conv2d-59            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-60            [-1, 128, 8, 8]             256
#              ReLU-61            [-1, 128, 8, 8]               0
#            Conv2d-62            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-63            [-1, 128, 8, 8]             256
#              ReLU-64            [-1, 128, 8, 8]               0
#            Conv2d-65            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-66            [-1, 512, 8, 8]           1,024
#              ReLU-67            [-1, 512, 8, 8]               0
#        Bottleneck-68            [-1, 512, 8, 8]               0
#            Conv2d-69            [-1, 128, 8, 8]          65,536
#       BatchNorm2d-70            [-1, 128, 8, 8]             256
#              ReLU-71            [-1, 128, 8, 8]               0
#            Conv2d-72            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-73            [-1, 128, 8, 8]             256
#              ReLU-74            [-1, 128, 8, 8]               0
#            Conv2d-75            [-1, 512, 8, 8]          65,536
#       BatchNorm2d-76            [-1, 512, 8, 8]           1,024
#              ReLU-77            [-1, 512, 8, 8]               0
#        Bottleneck-78            [-1, 512, 8, 8]               0
#            Conv2d-79            [-1, 256, 8, 8]         131,072
#       BatchNorm2d-80            [-1, 256, 8, 8]             512
#              ReLU-81            [-1, 256, 8, 8]               0
#            Conv2d-82            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-83            [-1, 256, 4, 4]             512
#              ReLU-84            [-1, 256, 4, 4]               0
#            Conv2d-85           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-86           [-1, 1024, 4, 4]           2,048
#            Conv2d-87           [-1, 1024, 4, 4]         524,288
#       BatchNorm2d-88           [-1, 1024, 4, 4]           2,048
#              ReLU-89           [-1, 1024, 4, 4]               0
#        Bottleneck-90           [-1, 1024, 4, 4]               0
#            Conv2d-91            [-1, 256, 4, 4]         262,144
#       BatchNorm2d-92            [-1, 256, 4, 4]             512
#              ReLU-93            [-1, 256, 4, 4]               0
#            Conv2d-94            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-95            [-1, 256, 4, 4]             512
#              ReLU-96            [-1, 256, 4, 4]               0
#            Conv2d-97           [-1, 1024, 4, 4]         262,144
#       BatchNorm2d-98           [-1, 1024, 4, 4]           2,048
#              ReLU-99           [-1, 1024, 4, 4]               0
#       Bottleneck-100           [-1, 1024, 4, 4]               0
#           Conv2d-101            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-102            [-1, 256, 4, 4]             512
#             ReLU-103            [-1, 256, 4, 4]               0
#           Conv2d-104            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-105            [-1, 256, 4, 4]             512
#             ReLU-106            [-1, 256, 4, 4]               0
#           Conv2d-107           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-108           [-1, 1024, 4, 4]           2,048
#             ReLU-109           [-1, 1024, 4, 4]               0
#       Bottleneck-110           [-1, 1024, 4, 4]               0
#           Conv2d-111            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-112            [-1, 256, 4, 4]             512
#             ReLU-113            [-1, 256, 4, 4]               0
#           Conv2d-114            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-115            [-1, 256, 4, 4]             512
#             ReLU-116            [-1, 256, 4, 4]               0
#           Conv2d-117           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-118           [-1, 1024, 4, 4]           2,048
#             ReLU-119           [-1, 1024, 4, 4]               0
#       Bottleneck-120           [-1, 1024, 4, 4]               0
#           Conv2d-121            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-122            [-1, 256, 4, 4]             512
#             ReLU-123            [-1, 256, 4, 4]               0
#           Conv2d-124            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-125            [-1, 256, 4, 4]             512
#             ReLU-126            [-1, 256, 4, 4]               0
#           Conv2d-127           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-128           [-1, 1024, 4, 4]           2,048
#             ReLU-129           [-1, 1024, 4, 4]               0
#       Bottleneck-130           [-1, 1024, 4, 4]               0
#           Conv2d-131            [-1, 256, 4, 4]         262,144
#      BatchNorm2d-132            [-1, 256, 4, 4]             512
#             ReLU-133            [-1, 256, 4, 4]               0
#           Conv2d-134            [-1, 256, 4, 4]         589,824
#      BatchNorm2d-135            [-1, 256, 4, 4]             512
#             ReLU-136            [-1, 256, 4, 4]               0
#           Conv2d-137           [-1, 1024, 4, 4]         262,144
#      BatchNorm2d-138           [-1, 1024, 4, 4]           2,048
#             ReLU-139           [-1, 1024, 4, 4]               0
#       Bottleneck-140           [-1, 1024, 4, 4]               0
#           Conv2d-141            [-1, 512, 4, 4]         524,288
#      BatchNorm2d-142            [-1, 512, 4, 4]           1,024
#             ReLU-143            [-1, 512, 4, 4]               0
#           Conv2d-144            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-145            [-1, 512, 2, 2]           1,024
#             ReLU-146            [-1, 512, 2, 2]               0
#           Conv2d-147           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 2, 2]           4,096
#           Conv2d-149           [-1, 2048, 2, 2]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 2, 2]           4,096
#             ReLU-151           [-1, 2048, 2, 2]               0
#       Bottleneck-152           [-1, 2048, 2, 2]               0
#           Conv2d-153            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-154            [-1, 512, 2, 2]           1,024
#             ReLU-155            [-1, 512, 2, 2]               0
#           Conv2d-156            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-157            [-1, 512, 2, 2]           1,024
#             ReLU-158            [-1, 512, 2, 2]               0
#           Conv2d-159           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 2, 2]           4,096
#             ReLU-161           [-1, 2048, 2, 2]               0
#       Bottleneck-162           [-1, 2048, 2, 2]               0
#           Conv2d-163            [-1, 512, 2, 2]       1,048,576
#      BatchNorm2d-164            [-1, 512, 2, 2]           1,024
#             ReLU-165            [-1, 512, 2, 2]               0
#           Conv2d-166            [-1, 512, 2, 2]       2,359,296
#      BatchNorm2d-167            [-1, 512, 2, 2]           1,024
#             ReLU-168            [-1, 512, 2, 2]               0
#           Conv2d-169           [-1, 2048, 2, 2]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 2, 2]           4,096
#             ReLU-171           [-1, 2048, 2, 2]               0
#       Bottleneck-172           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 23,520,842
# Trainable params: 23,520,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 23.41
# Params size (MB): 89.72
# Estimated Total Size (MB): 113.14
# ----------------------------------------------------------------

# %% [markdown]
# ## 設定超參數(請填空 λ)

# %%
SPARSITY_REGULARIZATION = True
#### 設定λ(balance factor) ####
################################################
#          請填空          #
################################################
LAMBDA = 1e-4  # 0 or 1e-5 or 1e-4

SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000

EPOCHS = 40
LEARNING_RATE = 1e-3

LOG_INTERVAL = 100
CUDA = True

RESUME = False
START_EPOCH = 0

WEIGHT_PATH = 'model_best.pth' # Change to your own folder !!!

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### 資料集 ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 定義模型與設定Optimizer & CrossEntropy Loss

# %%
# cfg = [64, 64, 64, 256, 64, 64, 256, 64, 64, 256, 128, 128, 512, 128, 128, 512, 128, 128, 512, 128, 128, 512, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 256, 256, 1024, 512, 512, 2048, 512, 512, 2048, 512, 512, 2048]

model = ResNet50(num_classes=10)
if CUDA:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 使用論文中稀疏化的方式更新參數(請填空)

# %%
def updateBN():
  for m in model.modules():
      if isinstance(m, nn.BatchNorm2d):
          #### 完成Sparsity Regularization ####
          ################################################
          #          請填空          #
          ################################################
          
          # 在稀疏化訓練中，對 BN 的 weight 加上梯度 = λ * sign(weight)
          m.weight.grad.data.add_(LAMBDA * torch.sign(m.weight.data))

# %% [markdown]
# ## 定義訓練跟測試函數
# 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc與test acc的code，以便後續繪製train acc與test acc結果圖!

train_acc_list = []
test_acc_list = []

def train(epoch):
    model.train()
    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()

        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)

        loss = criterion(output, target)
        loss.backward()

        # ----------- Sparsity Regularization -----------
        if SPARSITY_REGULARIZATION:
            updateBN()
        optimizer.step()
        # ------------------------------------------------

        # === 計算本 batch 正確數 ===
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum().item()
        total += target.size(0)

        # === 每 LOG_INTERVAL 顯示一次訓練狀態 ===
        if batch_idx % LOG_INTERVAL == 0:
            print('Train Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

    # === 計算整個 epoch 的訓練集準確率 ===
    acc = correct / total
    train_acc_list.append(acc)
    print(f'Epoch {epoch}: Train Accuracy = {acc:.4f}')


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            if CUDA:
                data, target = data.cuda(), target.cuda()
            data, target = Variable(data), Variable(target)

            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item() * data.size(0)

            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / float(len(test_loader.dataset))
    test_acc_list.append(acc)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return acc


##########################################################################################

best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate 在 0.5EPOCHS 與 0.75EPOCHS 調整為原本 1/10
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1

    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便後續剪枝與微調
    if prec1 > best_prec1:
        best_prec1 = prec1
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, WEIGHT_PATH)

    best_prec1 = max(prec1, best_prec1)
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.618000
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 1.814992
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 1.711462
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 1.895940
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 1.455839
# Epoch 0: Train Accuracy = 0.3569
#
# Test set: Average loss: 1.3895, Accuracy: 4894/10000 (48.9%)
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 1.450131
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.484389
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.439680
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.446298
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.162574
# Epoch 1: Train Accuracy = 0.5206
#
# Test set: Average loss: 1.5470, Accuracy: 5693/10000 (56.9%)
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 1.177970
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 1.138844
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 1.096656
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 1.193257
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.988427
# Epoch 2: Train Accuracy = 0.6129
#
# Test set: Average loss: 0.9643, Accuracy: 6612/10000 (66.1%)
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.865689
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.653424
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.963206
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.962332
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 1.022583
# Epoch 3: Train Accuracy = 0.6810
#
# Test set: Average loss: 0.8177, Accuracy: 7092/10000 (70.9%)
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.838152
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.805148
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.827939
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.798528
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.669007
# Epoch 4: Train Accuracy = 0.7226
#
# Test set: Average loss: 0.8247, Accuracy: 7149/10000 (71.5%)
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.699521
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.661395
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.781432
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.708157
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.837095
# Epoch 5: Train Accuracy = 0.7559
#
# Test set: Average loss: 0.6833, Accuracy: 7670/10000 (76.7%)
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.664642
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.600311
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.538087
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.641066
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.609215
# Epoch 6: Train Accuracy = 0.7782
#
# Test set: Average loss: 0.6375, Accuracy: 7768/10000 (77.7%)
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.601958
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.591282
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.738911
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.612084
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.619235
# Epoch 7: Train Accuracy = 0.7987
#
# Test set: Average loss: 0.5370, Accuracy: 8164/10000 (81.6%)
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.519099
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.505053
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.633246
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.587608
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.539220
# Epoch 8: Train Accuracy = 0.8123
#
# Test set: Average loss: 0.6246, Accuracy: 7903/10000 (79.0%)
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.620832
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.387747
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.586246
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.541561
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.559230
# Epoch 9: Train Accuracy = 0.8244
#
# Test set: Average loss: 0.5189, Accuracy: 8238/10000 (82.4%)
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.412192
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.406392
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.530802
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.370150
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.351870
# Epoch 10: Train Accuracy = 0.8342
#
# Test set: Average loss: 0.5267, Accuracy: 8199/10000 (82.0%)
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.455403
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.375460
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.324523
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.317489
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.383877
# Epoch 11: Train Accuracy = 0.8440
#
# Test set: Average loss: 0.4841, Accuracy: 8330/10000 (83.3%)
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.467191
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.327858
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.473852
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.468488
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.570128
# Epoch 12: Train Accuracy = 0.8526
#
# Test set: Average loss: 0.4687, Accuracy: 8410/10000 (84.1%)
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.248927
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.471290
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.533806
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.468109
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.352794
# Epoch 13: Train Accuracy = 0.8605
#
# Test set: Average loss: 0.4863, Accuracy: 8370/10000 (83.7%)
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.260942
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.431447
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.522657
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.399064
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.391792
# Epoch 14: Train Accuracy = 0.8669
#
# Test set: Average loss: 0.4447, Accuracy: 8489/10000 (84.9%)
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.407709
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.326061
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.399325
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.356479
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.356496
# Epoch 15: Train Accuracy = 0.8745
#
# Test set: Average loss: 0.4287, Accuracy: 8589/10000 (85.9%)
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.283048
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.229022
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.451168
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.188721
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.298752
# Epoch 16: Train Accuracy = 0.8788
#
# Test set: Average loss: 0.4274, Accuracy: 8564/10000 (85.6%)
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.323266
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.482115
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.310598
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.267386
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.357053
# Epoch 17: Train Accuracy = 0.8830
#
# Test set: Average loss: 0.4170, Accuracy: 8566/10000 (85.7%)
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.255944
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.323368
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.596578
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.213509
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.380150
# Epoch 18: Train Accuracy = 0.8904
#
# Test set: Average loss: 0.4163, Accuracy: 8626/10000 (86.3%)
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.285187
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.233222
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.282147
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.404533
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.238647
# Epoch 19: Train Accuracy = 0.8945
#
# Test set: Average loss: 0.3840, Accuracy: 8711/10000 (87.1%)
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.274608
# Train Epoch: 20 [10000/50000 (20.0%)]	Loss: 0.167455
# Train Epoch: 20 [20000/50000 (40.0%)]	Loss: 0.142405
# Train Epoch: 20 [30000/50000 (60.0%)]	Loss: 0.260718
# Train Epoch: 20 [40000/50000 (80.0%)]	Loss: 0.358783
# Epoch 20: Train Accuracy = 0.9282
#
# Test set: Average loss: 0.2972, Accuracy: 9005/10000 (90.0%)
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.243857
# Train Epoch: 21 [10000/50000 (20.0%)]	Loss: 0.137724
# Train Epoch: 21 [20000/50000 (40.0%)]	Loss: 0.222227
# Train Epoch: 21 [30000/50000 (60.0%)]	Loss: 0.138639
# Train Epoch: 21 [40000/50000 (80.0%)]	Loss: 0.188083
# Epoch 21: Train Accuracy = 0.9365
#
# Test set: Average loss: 0.2987, Accuracy: 9036/10000 (90.4%)
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.176438
# Train Epoch: 22 [10000/50000 (20.0%)]	Loss: 0.120416
# Train Epoch: 22 [20000/50000 (40.0%)]	Loss: 0.100814
# Train Epoch: 22 [30000/50000 (60.0%)]	Loss: 0.088810
# Train Epoch: 22 [40000/50000 (80.0%)]	Loss: 0.232894
# Epoch 22: Train Accuracy = 0.9405
#
# Test set: Average loss: 0.2947, Accuracy: 9052/10000 (90.5%)
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.158565
# Train Epoch: 23 [10000/50000 (20.0%)]	Loss: 0.144209
# Train Epoch: 23 [20000/50000 (40.0%)]	Loss: 0.181609
# Train Epoch: 23 [30000/50000 (60.0%)]	Loss: 0.241423
# Train Epoch: 23 [40000/50000 (80.0%)]	Loss: 0.174078
# Epoch 23: Train Accuracy = 0.9443
#
# Test set: Average loss: 0.2965, Accuracy: 9055/10000 (90.5%)
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.093973
# Train Epoch: 24 [10000/50000 (20.0%)]	Loss: 0.143778
# Train Epoch: 24 [20000/50000 (40.0%)]	Loss: 0.249337
# Train Epoch: 24 [30000/50000 (60.0%)]	Loss: 0.076734
# Train Epoch: 24 [40000/50000 (80.0%)]	Loss: 0.094211
# Epoch 24: Train Accuracy = 0.9463
#
# Test set: Average loss: 0.2936, Accuracy: 9076/10000 (90.8%)
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.060069
# Train Epoch: 25 [10000/50000 (20.0%)]	Loss: 0.275017
# Train Epoch: 25 [20000/50000 (40.0%)]	Loss: 0.166317
# Train Epoch: 25 [30000/50000 (60.0%)]	Loss: 0.263402
# Train Epoch: 25 [40000/50000 (80.0%)]	Loss: 0.084324
# Epoch 25: Train Accuracy = 0.9490
#
# Test set: Average loss: 0.2969, Accuracy: 9057/10000 (90.6%)
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.141480
# Train Epoch: 26 [10000/50000 (20.0%)]	Loss: 0.091041
# Train Epoch: 26 [20000/50000 (40.0%)]	Loss: 0.113461
# Train Epoch: 26 [30000/50000 (60.0%)]	Loss: 0.208902
# Train Epoch: 26 [40000/50000 (80.0%)]	Loss: 0.116605
# Epoch 26: Train Accuracy = 0.9498
#
# Test set: Average loss: 0.2978, Accuracy: 9064/10000 (90.6%)
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.100858
# Train Epoch: 27 [10000/50000 (20.0%)]	Loss: 0.101603
# Train Epoch: 27 [20000/50000 (40.0%)]	Loss: 0.146729
# Train Epoch: 27 [30000/50000 (60.0%)]	Loss: 0.105548
# Train Epoch: 27 [40000/50000 (80.0%)]	Loss: 0.148010
# Epoch 27: Train Accuracy = 0.9529
#
# Test set: Average loss: 0.3000, Accuracy: 9065/10000 (90.7%)
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.106203
# Train Epoch: 28 [10000/50000 (20.0%)]	Loss: 0.182999
# Train Epoch: 28 [20000/50000 (40.0%)]	Loss: 0.131765
# Train Epoch: 28 [30000/50000 (60.0%)]	Loss: 0.106976
# Train Epoch: 28 [40000/50000 (80.0%)]	Loss: 0.194405
# Epoch 28: Train Accuracy = 0.9537
#
# Test set: Average loss: 0.2996, Accuracy: 9113/10000 (91.1%)
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.127059
# Train Epoch: 29 [10000/50000 (20.0%)]	Loss: 0.202870
# Train Epoch: 29 [20000/50000 (40.0%)]	Loss: 0.091684
# Train Epoch: 29 [30000/50000 (60.0%)]	Loss: 0.172446
# Train Epoch: 29 [40000/50000 (80.0%)]	Loss: 0.127001
# Epoch 29: Train Accuracy = 0.9561
#
# Test set: Average loss: 0.2988, Accuracy: 9068/10000 (90.7%)
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.121806
# Train Epoch: 30 [10000/50000 (20.0%)]	Loss: 0.153926
# Train Epoch: 30 [20000/50000 (40.0%)]	Loss: 0.101606
# Train Epoch: 30 [30000/50000 (60.0%)]	Loss: 0.121319
# Train Epoch: 30 [40000/50000 (80.0%)]	Loss: 0.148063
# Epoch 30: Train Accuracy = 0.9596
#
# Test set: Average loss: 0.2933, Accuracy: 9079/10000 (90.8%)
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.113571
# Train Epoch: 31 [10000/50000 (20.0%)]	Loss: 0.080665
# Train Epoch: 31 [20000/50000 (40.0%)]	Loss: 0.131314
# Train Epoch: 31 [30000/50000 (60.0%)]	Loss: 0.082851
# Train Epoch: 31 [40000/50000 (80.0%)]	Loss: 0.058072
# Epoch 31: Train Accuracy = 0.9597
#
# Test set: Average loss: 0.2932, Accuracy: 9091/10000 (90.9%)
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.098191
# Train Epoch: 32 [10000/50000 (20.0%)]	Loss: 0.162701
# Train Epoch: 32 [20000/50000 (40.0%)]	Loss: 0.070507
# Train Epoch: 32 [30000/50000 (60.0%)]	Loss: 0.201072
# Train Epoch: 32 [40000/50000 (80.0%)]	Loss: 0.083979
# Epoch 32: Train Accuracy = 0.9611
#
# Test set: Average loss: 0.2928, Accuracy: 9098/10000 (91.0%)
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.102851
# Train Epoch: 33 [10000/50000 (20.0%)]	Loss: 0.093450
# Train Epoch: 33 [20000/50000 (40.0%)]	Loss: 0.105318
# Train Epoch: 33 [30000/50000 (60.0%)]	Loss: 0.196223
# Train Epoch: 33 [40000/50000 (80.0%)]	Loss: 0.116278
# Epoch 33: Train Accuracy = 0.9615
#
# Test set: Average loss: 0.2939, Accuracy: 9114/10000 (91.1%)
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.159424
# Train Epoch: 34 [10000/50000 (20.0%)]	Loss: 0.064207
# Train Epoch: 34 [20000/50000 (40.0%)]	Loss: 0.073771
# Train Epoch: 34 [30000/50000 (60.0%)]	Loss: 0.111104
# Train Epoch: 34 [40000/50000 (80.0%)]	Loss: 0.180301
# Epoch 34: Train Accuracy = 0.9606
#
# Test set: Average loss: 0.2918, Accuracy: 9095/10000 (91.0%)
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.052212
# Train Epoch: 35 [10000/50000 (20.0%)]	Loss: 0.139717
# Train Epoch: 35 [20000/50000 (40.0%)]	Loss: 0.122431
# Train Epoch: 35 [30000/50000 (60.0%)]	Loss: 0.074245
# Train Epoch: 35 [40000/50000 (80.0%)]	Loss: 0.104777
# Epoch 35: Train Accuracy = 0.9605
#
# Test set: Average loss: 0.2911, Accuracy: 9096/10000 (91.0%)
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.113754
# Train Epoch: 36 [10000/50000 (20.0%)]	Loss: 0.121579
# Train Epoch: 36 [20000/50000 (40.0%)]	Loss: 0.123022
# Train Epoch: 36 [30000/50000 (60.0%)]	Loss: 0.174757
# Train Epoch: 36 [40000/50000 (80.0%)]	Loss: 0.097957
# Epoch 36: Train Accuracy = 0.9623
#
# Test set: Average loss: 0.2943, Accuracy: 9103/10000 (91.0%)
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.147580
# Train Epoch: 37 [10000/50000 (20.0%)]	Loss: 0.145326
# Train Epoch: 37 [20000/50000 (40.0%)]	Loss: 0.053992
# Train Epoch: 37 [30000/50000 (60.0%)]	Loss: 0.083893
# Train Epoch: 37 [40000/50000 (80.0%)]	Loss: 0.101504
# Epoch 37: Train Accuracy = 0.9602
#
# Test set: Average loss: 0.2938, Accuracy: 9105/10000 (91.0%)
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.069637
# Train Epoch: 38 [10000/50000 (20.0%)]	Loss: 0.139176
# Train Epoch: 38 [20000/50000 (40.0%)]	Loss: 0.150514
# Train Epoch: 38 [30000/50000 (60.0%)]	Loss: 0.081757
# Train Epoch: 38 [40000/50000 (80.0%)]	Loss: 0.092678
# Epoch 38: Train Accuracy = 0.9610
#
# Test set: Average loss: 0.2947, Accuracy: 9097/10000 (91.0%)
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.066915
# Train Epoch: 39 [10000/50000 (20.0%)]	Loss: 0.238051
# Train Epoch: 39 [20000/50000 (40.0%)]	Loss: 0.086763
# Train Epoch: 39 [30000/50000 (60.0%)]	Loss: 0.082553
# Train Epoch: 39 [40000/50000 (80.0%)]	Loss: 0.099386
# Epoch 39: Train Accuracy = 0.9628
#
# Test set: Average loss: 0.2952, Accuracy: 9100/10000 (91.0%)

# %% [markdown]
# ## 繪製Sparsity-Training結果圖

# %%
save_dir = "./results"
os.makedirs(save_dir, exist_ok=True)

# %%
#繪製 Sparsity-Training 結果圖


train_acc_percent = [acc * 100 for acc in train_acc_list]
test_acc_percent = [acc * 100 for acc in test_acc_list]

epochs = range(1, EPOCHS + 1)
plt.figure(figsize=(8,5))
plt.plot(epochs, train_acc_percent, label='Train Accuracy', marker='o')
plt.plot(epochs, test_acc_percent, label='Test Accuracy', marker='s')
plt.title(f"Sparsity Training (λ = {LAMBDA})")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.legend()
# plt.grid(True, linestyle="--", alpha=0.6)
plt.grid(True)

plt.tight_layout()

save_path = os.path.join(save_dir, f"sparsity_training_acc_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()

# %% [markdown]
# ## 繪製scaling factor 分布圖

# %%
#繪製 scaling factor 分布圖


all_gamma = []
for m in model.modules():
    if isinstance(m, nn.BatchNorm2d):
        all_gamma.append(m.weight.data.abs().cpu().numpy())

# 合併所有 γ 值
all_gamma = np.concatenate(all_gamma)

plt.figure(figsize=(7,4))
plt.hist(all_gamma, bins=80, color='skyblue', edgecolor='k', alpha=0.7)
plt.title(f"Distribution of BN Scaling Factors (λ = {LAMBDA})")
plt.xlabel("γ (BatchNorm scale)")
plt.ylabel("Frequency")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()



save_path = os.path.join(save_dir, f"bn_distribution_lambda_{LAMBDA}.png")
plt.savefig(save_path, dpi=300)
plt.show()
