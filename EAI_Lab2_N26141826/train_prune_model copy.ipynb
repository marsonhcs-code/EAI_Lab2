# %% [markdown]
# ## 掛載雲端硬碟

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/your own folder/

# %% [markdown]
# ## Import library

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import matplotlib.pyplot as plt

from models_copy.resnet import ResNet50

# %% [markdown]
# ## 設定超參數

# %%
SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 20
LEARNING_RATE = 1e-3
LOG_INTERVAL = 100
CUDA = True

RESUME = True
START_EPOCH = 0

PRUNE_PATH = 'model_prune.pth' # Change to your own folder !!!
PRUNE_FINETUNE_PATH = 'model_prune_finetune.pth' # Change to your own folder !!!

# %% [markdown]
# #### 檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  cfg = checkpoint['cfg']
  model = ResNet50(num_classes=10,cfg=cfg)
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# cfg loaded from prune model:  [64, 64, 64, 256, 64, 64, 256, 64, 64, 256, 125, 120, 512, 88, 105, 512, 58, 65, 512, 58, 64, 512, 77, 71, 1024, 17, 51, 1024, 5, 12, 1024, 2, 6, 1024, 3, 1, 1024, 3, 3, 1024, 3, 3, 2048, 3, 3, 2048, 3, 3, 2048]
# RESUME PRUNE MODEL

# %% [markdown]
# ## 設定 Optimizer & CrossEntropy Loss

# %%
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!
train_acc_list = []
test_acc_list = []

def train(epoch):
    model.train()
    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum().item()
        total += target.size(0)

        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

    acc = 100. * correct / total
    train_acc_list.append(acc)
    print(f"Train Accuracy: {acc:.2f}%")
    return acc


#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for data, target in test_loader:
            if CUDA:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item() * data.size(0)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).cpu().sum().item()

    test_loss /= len(test_loader.dataset)
    acc = 100. * correct / len(test_loader.dataset)
    test_acc_list.append(acc)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset), acc))
    return acc


#### Fine-tune 訓練主迴圈 ####
best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # 動態調整學習率
    if epoch in [int(EPOCHS * 0.5), int(EPOCHS * 0.75)]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1

    train_acc = train(epoch)
    test_acc = test()

    # 儲存最佳模型
    if test_acc > best_prec1:
        best_prec1 = test_acc
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
            'cfg': cfg
        }, PRUNE_FINETUNE_PATH)
    best_prec1 = max(test_acc, best_prec1)

print('\nTRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 0.460873
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 0.213937
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 0.506406
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 0.267894
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 0.358369
# Train Accuracy: 88.74%
#
# Test set: Average loss: 0.4042, Accuracy: 8686/10000 (86.9%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.161958
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 0.192786
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 0.187335
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 0.311910
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 0.194761
# Train Accuracy: 90.02%
#
# Test set: Average loss: 0.4002, Accuracy: 8729/10000 (87.3%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.329802
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.177160
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 0.396015
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.181429
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.225267
# Train Accuracy: 90.64%
#
# Test set: Average loss: 0.3901, Accuracy: 8764/10000 (87.6%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.349260
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.269309
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.281295
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.268479
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.244223
# Train Accuracy: 90.94%
#
# Test set: Average loss: 0.3741, Accuracy: 8813/10000 (88.1%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.224837
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.171142
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.274247
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.192454
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.281628
# Train Accuracy: 91.27%
#
# Test set: Average loss: 0.3883, Accuracy: 8737/10000 (87.4%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.328892
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.209134
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.225155
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.191295
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.242087
# Train Accuracy: 91.50%
#
# Test set: Average loss: 0.3707, Accuracy: 8827/10000 (88.3%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.226360
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.111529
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.303138
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.236003
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.260793
# Train Accuracy: 91.81%
#
# Test set: Average loss: 0.4037, Accuracy: 8776/10000 (87.8%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.295340
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.147551
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.230209
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.299829
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.323306
# Train Accuracy: 91.98%
#
# Test set: Average loss: 0.3736, Accuracy: 8816/10000 (88.2%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.181137
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.171487
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.202236
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.275734
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.232554
# Train Accuracy: 92.39%
#
# Test set: Average loss: 0.3949, Accuracy: 8810/10000 (88.1%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.171772
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.152212
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.264828
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.241683
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.189224
# Train Accuracy: 92.50%
#
# Test set: Average loss: 0.3775, Accuracy: 8868/10000 (88.7%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.122328
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.163359
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.176659
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.069851
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.187312
# Train Accuracy: 95.00%
#
# Test set: Average loss: 0.2990, Accuracy: 9068/10000 (90.7%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.199790
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.101627
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.079853
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.101490
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.128434
# Train Accuracy: 95.90%
#
# Test set: Average loss: 0.2980, Accuracy: 9101/10000 (91.0%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.097635
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.123633
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.058164
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.095400
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.053423
# Train Accuracy: 96.25%
#
# Test set: Average loss: 0.3043, Accuracy: 9100/10000 (91.0%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.102954
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.106072
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.157199
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.049889
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.099360
# Train Accuracy: 96.48%
#
# Test set: Average loss: 0.3150, Accuracy: 9105/10000 (91.0%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.097989
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.169656
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.055587
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.148556
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.166487
# Train Accuracy: 96.71%
#
# Test set: Average loss: 0.3134, Accuracy: 9116/10000 (91.2%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.087849
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.060593
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.087769
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.107455
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.156136
# Train Accuracy: 96.94%
#
# Test set: Average loss: 0.3096, Accuracy: 9136/10000 (91.4%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.040909
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.171152
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.092174
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.051575
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.179878
# Train Accuracy: 97.13%
#
# Test set: Average loss: 0.3120, Accuracy: 9128/10000 (91.3%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.045233
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.031952
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.066691
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.141515
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.040258
# Train Accuracy: 97.13%
#
# Test set: Average loss: 0.3120, Accuracy: 9129/10000 (91.3%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.055622
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.039666
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.104738
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.108806
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.129651
# Train Accuracy: 97.03%
#
# Test set: Average loss: 0.3127, Accuracy: 9122/10000 (91.2%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.137514
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.153637
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.151239
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.044441
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.035429
# Train Accuracy: 97.19%
#
# Test set: Average loss: 0.3087, Accuracy: 9149/10000 (91.5%)
#
#
# TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
save_dir = "./results"
os.makedirs(save_dir, exist_ok=True)

# %%
#繪製Fine-tuning結果圖
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(train_acc_list) + 1), train_acc_list, label='Train Accuracy', marker='o')
plt.plot(range(1, len(test_acc_list) + 1), test_acc_list, label='Test Accuracy', marker='s')
plt.title('Fine-tuning Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.tight_layout()
save_path = os.path.join(save_dir, f"fine_tune_result.png")
plt.savefig(save_path, dpi=300)
plt.show()

# %% [markdown]
# ## FLOPs & Parameters

# %%
# !pip install thop
# !pip install torchsummary
# Out:
# Requirement already satisfied: thop in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from thop) (2.6.0+cu124)
# Requirement already satisfied: filelock in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: networkx in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (3.2.0)
# Requirement already satisfied: setuptools in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (from jinja2->torch->thop) (2.1.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchsummary in /home/n26141826/EAI_Lab2/.venv/lib/python3.12/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from thop import profile
from torchsummary import summary

##### 使用 thop 計算 FLOPs 和參數數量 #####
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 135962780.0
# Params: 3941001.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-14          [-1, 256, 16, 16]             512
#              ReLU-15          [-1, 256, 16, 16]               0
#        Bottleneck-16          [-1, 256, 16, 16]               0
#            Conv2d-17           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-18           [-1, 64, 16, 16]             128
#              ReLU-19           [-1, 64, 16, 16]               0
#            Conv2d-20           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-21           [-1, 64, 16, 16]             128
#              ReLU-22           [-1, 64, 16, 16]               0
#            Conv2d-23          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-24          [-1, 256, 16, 16]             512
#              ReLU-25          [-1, 256, 16, 16]               0
#        Bottleneck-26          [-1, 256, 16, 16]               0
#            Conv2d-27           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-28           [-1, 64, 16, 16]             128
#              ReLU-29           [-1, 64, 16, 16]               0
#            Conv2d-30           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-31           [-1, 64, 16, 16]             128
#              ReLU-32           [-1, 64, 16, 16]               0
#            Conv2d-33          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-34          [-1, 256, 16, 16]             512
#              ReLU-35          [-1, 256, 16, 16]               0
#        Bottleneck-36          [-1, 256, 16, 16]               0
#            Conv2d-37          [-1, 125, 16, 16]          32,000
#       BatchNorm2d-38          [-1, 125, 16, 16]             250
#              ReLU-39          [-1, 125, 16, 16]               0
#            Conv2d-40            [-1, 120, 8, 8]         135,000
#       BatchNorm2d-41            [-1, 120, 8, 8]             240
#              ReLU-42            [-1, 120, 8, 8]               0
#            Conv2d-43            [-1, 512, 8, 8]          61,440
#       BatchNorm2d-44            [-1, 512, 8, 8]           1,024
#            Conv2d-45            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-46            [-1, 512, 8, 8]           1,024
#              ReLU-47            [-1, 512, 8, 8]               0
#        Bottleneck-48            [-1, 512, 8, 8]               0
#            Conv2d-49             [-1, 88, 8, 8]          45,056
#       BatchNorm2d-50             [-1, 88, 8, 8]             176
#              ReLU-51             [-1, 88, 8, 8]               0
#            Conv2d-52            [-1, 105, 8, 8]          83,160
#       BatchNorm2d-53            [-1, 105, 8, 8]             210
#              ReLU-54            [-1, 105, 8, 8]               0
#            Conv2d-55            [-1, 512, 8, 8]          53,760
#       BatchNorm2d-56            [-1, 512, 8, 8]           1,024
#              ReLU-57            [-1, 512, 8, 8]               0
#        Bottleneck-58            [-1, 512, 8, 8]               0
#            Conv2d-59             [-1, 58, 8, 8]          29,696
#       BatchNorm2d-60             [-1, 58, 8, 8]             116
#              ReLU-61             [-1, 58, 8, 8]               0
#            Conv2d-62             [-1, 65, 8, 8]          33,930
#       BatchNorm2d-63             [-1, 65, 8, 8]             130
#              ReLU-64             [-1, 65, 8, 8]               0
#            Conv2d-65            [-1, 512, 8, 8]          33,280
#       BatchNorm2d-66            [-1, 512, 8, 8]           1,024
#              ReLU-67            [-1, 512, 8, 8]               0
#        Bottleneck-68            [-1, 512, 8, 8]               0
#            Conv2d-69             [-1, 58, 8, 8]          29,696
#       BatchNorm2d-70             [-1, 58, 8, 8]             116
#              ReLU-71             [-1, 58, 8, 8]               0
#            Conv2d-72             [-1, 64, 8, 8]          33,408
#       BatchNorm2d-73             [-1, 64, 8, 8]             128
#              ReLU-74             [-1, 64, 8, 8]               0
#            Conv2d-75            [-1, 512, 8, 8]          32,768
#       BatchNorm2d-76            [-1, 512, 8, 8]           1,024
#              ReLU-77            [-1, 512, 8, 8]               0
#        Bottleneck-78            [-1, 512, 8, 8]               0
#            Conv2d-79             [-1, 77, 8, 8]          39,424
#       BatchNorm2d-80             [-1, 77, 8, 8]             154
#              ReLU-81             [-1, 77, 8, 8]               0
#            Conv2d-82             [-1, 71, 4, 4]          49,203
#       BatchNorm2d-83             [-1, 71, 4, 4]             142
#              ReLU-84             [-1, 71, 4, 4]               0
#            Conv2d-85           [-1, 1024, 4, 4]          72,704
#       BatchNorm2d-86           [-1, 1024, 4, 4]           2,048
#            Conv2d-87           [-1, 1024, 4, 4]         524,288
#       BatchNorm2d-88           [-1, 1024, 4, 4]           2,048
#              ReLU-89           [-1, 1024, 4, 4]               0
#        Bottleneck-90           [-1, 1024, 4, 4]               0
#            Conv2d-91             [-1, 17, 4, 4]          17,408
#       BatchNorm2d-92             [-1, 17, 4, 4]              34
#              ReLU-93             [-1, 17, 4, 4]               0
#            Conv2d-94             [-1, 51, 4, 4]           7,803
#       BatchNorm2d-95             [-1, 51, 4, 4]             102
#              ReLU-96             [-1, 51, 4, 4]               0
#            Conv2d-97           [-1, 1024, 4, 4]          52,224
#       BatchNorm2d-98           [-1, 1024, 4, 4]           2,048
#              ReLU-99           [-1, 1024, 4, 4]               0
#       Bottleneck-100           [-1, 1024, 4, 4]               0
#           Conv2d-101              [-1, 5, 4, 4]           5,120
#      BatchNorm2d-102              [-1, 5, 4, 4]              10
#             ReLU-103              [-1, 5, 4, 4]               0
#           Conv2d-104             [-1, 12, 4, 4]             540
#      BatchNorm2d-105             [-1, 12, 4, 4]              24
#             ReLU-106             [-1, 12, 4, 4]               0
#           Conv2d-107           [-1, 1024, 4, 4]          12,288
#      BatchNorm2d-108           [-1, 1024, 4, 4]           2,048
#             ReLU-109           [-1, 1024, 4, 4]               0
#       Bottleneck-110           [-1, 1024, 4, 4]               0
#           Conv2d-111              [-1, 2, 4, 4]           2,048
#      BatchNorm2d-112              [-1, 2, 4, 4]               4
#             ReLU-113              [-1, 2, 4, 4]               0
#           Conv2d-114              [-1, 6, 4, 4]             108
#      BatchNorm2d-115              [-1, 6, 4, 4]              12
#             ReLU-116              [-1, 6, 4, 4]               0
#           Conv2d-117           [-1, 1024, 4, 4]           6,144
#      BatchNorm2d-118           [-1, 1024, 4, 4]           2,048
#             ReLU-119           [-1, 1024, 4, 4]               0
#       Bottleneck-120           [-1, 1024, 4, 4]               0
#           Conv2d-121              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-122              [-1, 3, 4, 4]               6
#             ReLU-123              [-1, 3, 4, 4]               0
#           Conv2d-124              [-1, 1, 4, 4]              27
#      BatchNorm2d-125              [-1, 1, 4, 4]               2
#             ReLU-126              [-1, 1, 4, 4]               0
#           Conv2d-127           [-1, 1024, 4, 4]           1,024
#      BatchNorm2d-128           [-1, 1024, 4, 4]           2,048
#             ReLU-129           [-1, 1024, 4, 4]               0
#       Bottleneck-130           [-1, 1024, 4, 4]               0
#           Conv2d-131              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-132              [-1, 3, 4, 4]               6
#             ReLU-133              [-1, 3, 4, 4]               0
#           Conv2d-134              [-1, 3, 4, 4]              81
#      BatchNorm2d-135              [-1, 3, 4, 4]               6
#             ReLU-136              [-1, 3, 4, 4]               0
#           Conv2d-137           [-1, 1024, 4, 4]           3,072
#      BatchNorm2d-138           [-1, 1024, 4, 4]           2,048
#             ReLU-139           [-1, 1024, 4, 4]               0
#       Bottleneck-140           [-1, 1024, 4, 4]               0
#           Conv2d-141              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-142              [-1, 3, 4, 4]               6
#             ReLU-143              [-1, 3, 4, 4]               0
#           Conv2d-144              [-1, 3, 2, 2]              81
#      BatchNorm2d-145              [-1, 3, 2, 2]               6
#             ReLU-146              [-1, 3, 2, 2]               0
#           Conv2d-147           [-1, 2048, 2, 2]           6,144
#      BatchNorm2d-148           [-1, 2048, 2, 2]           4,096
#           Conv2d-149           [-1, 2048, 2, 2]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 2, 2]           4,096
#             ReLU-151           [-1, 2048, 2, 2]               0
#       Bottleneck-152           [-1, 2048, 2, 2]               0
#           Conv2d-153              [-1, 3, 2, 2]           6,144
#      BatchNorm2d-154              [-1, 3, 2, 2]               6
#             ReLU-155              [-1, 3, 2, 2]               0
#           Conv2d-156              [-1, 3, 2, 2]              81
#      BatchNorm2d-157              [-1, 3, 2, 2]               6
#             ReLU-158              [-1, 3, 2, 2]               0
#           Conv2d-159           [-1, 2048, 2, 2]           6,144
#      BatchNorm2d-160           [-1, 2048, 2, 2]           4,096
#             ReLU-161           [-1, 2048, 2, 2]               0
#       Bottleneck-162           [-1, 2048, 2, 2]               0
#           Conv2d-163              [-1, 3, 2, 2]           6,144
#      BatchNorm2d-164              [-1, 3, 2, 2]               6
#             ReLU-165              [-1, 3, 2, 2]               0
#           Conv2d-166              [-1, 3, 2, 2]              81
#      BatchNorm2d-167              [-1, 3, 2, 2]               6
#             ReLU-168              [-1, 3, 2, 2]               0
#           Conv2d-169           [-1, 2048, 2, 2]           6,144
#      BatchNorm2d-170           [-1, 2048, 2, 2]           4,096
#             ReLU-171           [-1, 2048, 2, 2]               0
#       Bottleneck-172           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                   [-1, 10]          20,490
# ================================================================
# Total params: 3,941,001
# Trainable params: 3,941,001
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 21.24
# Params size (MB): 15.03
# Estimated Total Size (MB): 36.29
# ----------------------------------------------------------------
